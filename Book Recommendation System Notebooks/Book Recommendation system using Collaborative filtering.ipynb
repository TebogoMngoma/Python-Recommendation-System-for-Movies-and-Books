# %% [markdown]
# # BOOK RECOMMENDATION SYSTEM
#
# ## What is a Recommendation System and Why is it important ?
#
# ![Image](books.jpg)
#
#
#
# A recommendation system is a software algorithm or system that suggests items, products, or content to users based on their preferences, behavior, or similarities to other users. These systems are designed to provide personalized and relevant recommendations, aiming to enhance user experience, engagement, and satisfaction.
#
# Recommendation systems are crucial in various domains, including e-commerce, entertainment, social media, and content streaming platforms
#
# We are going to build a Book recommendation system which can recommend us a book to read based on what are other read and also what books were rated the highest
#
# We are going to use two types of methods for our Recommendation System namely Collaborative and Content Based Filtering , on this particular we will be using Content based filtering
#
# ## Collaborative Filtering
#
# Collaborative Filtering tends to find what similar users would like and the recommendations to be provided and in order to classify the users into clusters of similar types and recommend each user according to the preference of its cluster. The main idea that governs the collaborative methods is that through past user-item interactions when processed through the system, it becomes sufficient to detect similar users or similar items to make predictions based on these estimated facts and insights

# %% [markdown]
# Import Packages

# %%
import pandas as pd
import numpy as np
import re
import matplotlib as plt
import json
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import coo_matrix

# %%
liked_books = pd.read_csv(r"C:\Users\PC\OneDrive\Documents\Movie Recommendation System\liked_books.csv")

# %% [markdown]
# ### Data Engineering

# %%
liked_books['book_id'] = liked_books['book_id'].astype(str)

# %%
csv_book_mapping = {}
with open(r"C:\Users\PC\OneDrive\Documents\Movie Recommendation System\book_id_map.csv") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id , book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

# %%
book_set = set(liked_books['book_id'])

# %%
overlap_users = {}
with open(r"C:\Users\PC\OneDrive\Documents\Movie Recommendation System\goodreads_interactions.csv") as f:
    
    while True:
        line = f.readline()
        if not line:
            break
        user_id , csv_id , _, rating, _ = line.strip().split(",")
        
        book_id = csv_book_mapping.get(csv_id)
        if book_id in book_set:
            if user_id not in overlap_users:
                overlap_users[user_id] = 1
            else:
                overlap_users[user_id] += 1

# %%
len(overlap_users)
# Out:
# 316341

# %% [markdown]
# We have to find users who have read the same books as ours and cut down users who do not share the same book as ours and this will also make computation for model building less intensive

# %%
filtered_overlap_users = set([k for k in overlap_users if overlap_users[k] > liked_books.shape[0]/5])

# %% [markdown]
# Below we create a list 'interactions_list' which grabs 'user_id' , 'book_id' and ratings for all the users

# %%
interactions_list = []
with open(r"C:\Users\PC\OneDrive\Documents\Movie Recommendation System\goodreads_interactions.csv") as f:
    
    while True:
        line = f.readline()
        if not line:
            break
        user_id , csv_id , _, rating, _ = line.strip().split(",")
        if user_id in filtered_overlap_users:
            book_id = csv_book_mapping[csv_id]
            interactions_list.append([user_id,book_id,rating])

# %% [markdown]
# ### Creating a user/book collaborative sparse matrix

# %%
interactions = pd.DataFrame(interactions_list, columns=['user_id','book_id','rating'])

# %% [markdown]
# Add our ratings into this matrix

# %%
interactions.head()
# Out:
#   user_id book_id rating
# 0     282  627206      4
# 1     282     960      4
# 2     282   15931      4
# 3     282   24178      3
# 4     282    6310      4

# %%
interactions = pd.concat([liked_books[['user_id','book_id','rating']], interactions])

# %%
interactions
# Out:
#         user_id   book_id rating
# 0            -1   2517439      5
# 1            -1    113576      5
# 2            -1     35100      5
# 3            -1    228221      5
# 4            -1  17662739      5
# ...         ...       ...    ...
# 5638696  804100    475178      0
# 5638697  804100    186074      0
# 5638698  804100    153008      0
# 5638699  804100     45107      0
# 5638700  804100   1762198      5
#
# [5638728 rows x 3 columns]

# %% [markdown]
# ### Data Engineering

# %% [markdown]
# convert each column to appropriate data type

# %%
interactions['book_id'] = interactions['book_id'].astype(str)
interactions['user_id'] = interactions['user_id'].astype(str)
interactions['rating'] = pd.to_numeric(interactions['rating'])

# %%
interactions['user_index'] = interactions['user_id'].astype('category').cat.codes

# %%
interactions['book_index'] = interactions['book_id'].astype('category').cat.codes

# %%
interactions
# Out:
#         user_id   book_id  rating  user_index  book_index
# 0            -1   2517439       5           0      414880
# 1            -1    113576       5           0       38971
# 2            -1     35100       5           0      575858
# 3            -1    228221       5           0      356004
# 4            -1  17662739       5           0      214285
# ...         ...       ...     ...         ...         ...
# 5638696  804100    475178       0        1183      617107
# 5638697  804100    186074       0        1183      258768
# 5638698  804100    153008       0        1183      141428
# 5638699  804100     45107       0        1183      611284
# 5638700  804100   1762198       5        1183      213203
#
# [5638728 rows x 5 columns]

# %%
ratings_mat_coo = coo_matrix((interactions['rating'] ,(interactions['user_index'],interactions['book_index'])))

# %%
ratings_mat = ratings_mat_coo.tocsr()

# %%
my_index = 0

# %% [markdown]
# Find users who have similar book taste to us

# %%
similarity = cosine_similarity(ratings_mat[my_index,:],ratings_mat).flatten()

# %%
similarity[2]
# Out:
# 0.06143442518998915

# %% [markdown]
# Find indices of users who are similar to us and find their positions

# %%
indices = np.argpartition(similarity,-15)[-15:]

# %%
indices
# Out:
# array([1188,  942,  218,  129,  496,  435, 1208,  795, 1213, 1210, 1143,
#         321,  294,  862,    0], dtype=int64)

# %% [markdown]
# Find id of users who are similar to us based on their indices

# %%
similar_users = interactions[interactions['user_index'].isin(indices)].copy()

# %%
similar_users
# Out:
#         user_id   book_id  rating  user_index  book_index
# 0            -1   2517439       5           0      414880
# 1            -1    113576       5           0       38971
# 2            -1     35100       5           0      575858
# 3            -1    228221       5           0      356004
# 4            -1  17662739       5           0      214285
# ...         ...       ...     ...         ...         ...
# 5638521  712588  32388712       3        1143      543119
# 5638522  712588     16322       5        1143      183365
# 5638523  712588    860543       0        1143      759827
# 5638524  712588    853510       5        1143      756768
# 5638525  712588     13890       4        1143      124251
#
# [4329 rows x 5 columns]

# %% [markdown]
# #### Creating Book Recommendations

# %%
book_recs = similar_users.groupby('book_id').rating.agg(['count','mean'])

# %%
book_recs
# Out:
#           count      mean
# book_id
# 1             6  3.833333
# 100322        1  0.000000
# 100365        1  0.000000
# 10046142      1  0.000000
# 1005          3  0.000000
# ...         ...       ...
# 99561         2  2.500000
# 99610         1  3.000000
# 99664         1  4.000000
# 9969571       3  2.333333
# 99944         1  0.000000
#
# [2869 rows x 2 columns]

# %% [markdown]
# import book titles to see the names of the books recommended as above we only just had the book id

# %%
book_titles = pd.read_json('book_titles.json')

# %%
#convert book id to string
book_titles['book_id'] = book_titles['book_id'].astype(str)

# %%
#now we merge the book titles with recommended books to display each book's title
book_recs = book_recs.merge(book_titles,how='inner',on='book_id')

# %%
book_recs['adjusted-count'] = book_recs['count'] * (book_recs['count']/book_recs['ratings'])

# %%
book_recs['score'] = book_recs['mean'] * book_recs['adjusted-count']

# %%
book_recs = book_recs[~book_recs['book_id'].isin(liked_books['book_id'])]

# %%
book_recs = book_recs[book_recs['mean'] > 3]

# %%
book_recs
# Out:
#        book_id  count      mean  \
# 0            1      6  3.833333
# 8     10079321      1  5.000000
# 11      100915      6  3.666667
# 12    10098912      2  3.500000
# 13     1009996      1  5.000000
# ...        ...    ...       ...
# 2814       960      9  3.444444
# 2815    961520      1  4.000000
# 2840   9832370      1  5.000000
# 2847     99085      1  5.000000
# 2859     99664      1  4.000000
#
#                                                   title  ratings  \
# 0     Harry Potter and the Half-Blood Prince (Harry ...  1713866
# 8                 The Magician King (The Magicians, #2)    53532
# 11    The Lion, the Witch, and the Wardrobe (Chronic...  1575387
# 12                                     Chanakya's Chant    15807
# 13    Artisan Bread in Five Minutes a Day: The Disco...    14456
# ...                                                 ...      ...
# 2814              Angels & Demons  (Robert Langdon, #1)  2046499
# 2815                       Yuganta: The End of an Epoch     1694
# 2840               BookRags Summary:  A Storm of Swords    19243
# 2847                      Lord Brocktree (Redwall, #13)    43677
# 2859                                   The Painted Veil    24606
#
#                                                     url  \
# 0     https://www.goodreads.com/book/show/1.Harry_Po...
# 8     https://www.goodreads.com/book/show/10079321-t...
# 11    https://www.goodreads.com/book/show/100915.The...
# 12    https://www.goodreads.com/book/show/10098912-c...
# 13    https://www.goodreads.com/book/show/1009996.Ar...
# ...                                                 ...
# 2814  https://www.goodreads.com/book/show/960.Angels...
# 2815  https://www.goodreads.com/book/show/961520.Yug...
# 2840  https://www.goodreads.com/book/show/9832370-bo...
# 2847  https://www.goodreads.com/book/show/99085.Lord...
# 2859  https://www.goodreads.com/book/show/99664.The_...
#
#                                             cover_image  \
# 0     https://images.gr-assets.com/books/1361039191m...
# 8     https://images.gr-assets.com/books/1316177353m...
# 11    https://images.gr-assets.com/books/1353029077m...
# 12    https://images.gr-assets.com/books/1327939570m...
# 13    https://images.gr-assets.com/books/1317064461m...
# ...                                                 ...
# 2814  https://images.gr-assets.com/books/1303390735m...
# 2815  https://images.gr-assets.com/books/1442640715m...
# 2840  https://images.gr-assets.com/books/1369340463m...
# 2847  https://s.gr-assets.com/assets/nophoto/book/11...
# 2859  https://images.gr-assets.com/books/1320421719m...
#
#                                             title_clean  adjusted-count  \
# 0     harry potter and the halfblood prince harry po...        0.000021
# 8                     the magician king the magicians 2        0.000019
# 11    the lion the witch and the wardrobe chronicles...        0.000023
# 12                                      chanakyas chant        0.000253
# 13    artisan bread in five minutes a day the discov...        0.000069
# ...                                                 ...             ...
# 2814                     angels demons robert langdon 1        0.000040
# 2815                        yuganta the end of an epoch        0.000590
# 2840                 bookrags summary a storm of swords        0.000052
# 2847                          lord brocktree redwall 13        0.000023
# 2859                                   the painted veil        0.000041
#
#          score
# 0     0.000081
# 8     0.000093
# 11    0.000084
# 12    0.000886
# 13    0.000346
# ...        ...
# 2814  0.000136
# 2815  0.002361
# 2840  0.000260
# 2847  0.000114
# 2859  0.000163
#
# [434 rows x 10 columns]

# %% [markdown]
# Our Top Recommended Books

# %%
top_recs = book_recs.sort_values("score",ascending=True)

# %% [markdown]
# Let's style our Dataframe to show the each book's image

# %%
def show_book_image(val):
    return '<img src={} width=50></img>'.format(val)
top_recs.style.format({'cover_image':show_book_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_591e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_591e3_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_591e3_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_591e3_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_591e3_level0_col3" class="col_heading level0 col3" >title</th>
#       <th id="T_591e3_level0_col4" class="col_heading level0 col4" >ratings</th>
#       <th id="T_591e3_level0_col5" class="col_heading level0 col5" >url</th>
#       <th id="T_591e3_level0_col6" class="col_heading level0 col6" >cover_image</th>
#       <th id="T_591e3_level0_col7" class="col_heading level0 col7" >title_clean</th>
#       <th id="T_591e3_level0_col8" class="col_heading level0 col8" >adjusted-count</th>
#       <th id="T_591e3_level0_col9" class="col_heading level0 col9" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_591e3_level0_row0" class="row_heading level0 row0" >2069</th>
#       <td id="T_591e3_row0_col0" class="data row0 col0" >5139</td>
#       <td id="T_591e3_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_591e3_row0_col2" class="data row0 col2" >4.000000</td>
#       <td id="T_591e3_row0_col3" class="data row0 col3" >The Devil Wears Prada (The Devil Wears Prada, #1)</td>
#       <td id="T_591e3_row0_col4" class="data row0 col4" >675927</td>
#       <td id="T_591e3_row0_col5" class="data row0 col5" >https://www.goodreads.com/book/show/5139.The_Devil_Wears_Prada</td>
#       <td id="T_591e3_row0_col6" class="data row0 col6" ><img src=https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png width=50></img></td>
#       <td id="T_591e3_row0_col7" class="data row0 col7" >the devil wears prada the devil wears prada 1</td>
#       <td id="T_591e3_row0_col8" class="data row0 col8" >0.000001</td>
#       <td id="T_591e3_row0_col9" class="data row0 col9" >0.000006</td>
#     </tr>
#     <tr>
#       <th id="T_591e3_level0_row1" class="row_heading level0 row1" >2666</th>
#       <td id="T_591e3_row1_col0" class="data row1 col0" >8442457</td>
#       <td id="T_591e3_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_591e3_row1_col2" class="data row1 col2" >4.000000</td>
#       <td id="T_591e3_row1_col3" class="data row1 col3" >Gone Girl</td>
#       <td id="T_591e3_row1_col4" class="data row1 col4" >513361</td>
#       <td id="T_591e3_row1_col5" class="data row1 col5" >https://www.goodreads.com/book/show/8442457-gone-girl</td>
#       <td id="T_591e3_row1_col6" class="data row1 col6" ><img src=https://images.gr-assets.com/books/1339602131m/8442457.jpg width=50></img></td>
#       <td id="T_591e3_row1_col7" class="data row1 col7" >gone girl</td>
#       <td id="T_591e3_row1_col8" class="data row1 col8" >0.000002</td>
#       <td id="T_591e3_row1_col9" class="data row1 col9" >0.000008</td>
#     </tr>
#     <tr>
#       <th id="T_591e3_level0_row2" class="row_heading level0 row2" >460</th>
#       <td id="T_591e3_row2_col0" class="data row2 col0" >137791</td>
#       <td id="T_591e3_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_591e3_row2_col2" class="data row2 col2" >4.000000</td>
#       <td id="T_591e3_row2_col3" class="data row2 col3" >Divine Secrets of the Ya-Ya Sisterhood</td>
#       <td id="T_591e3_row2_col4" class="data row2 col4" >469226</td>
#       <td id="T_591e3_row2_col5" class="data row2 col5" >https://www.goodreads.com/book/show/137791.Divine_Secrets_of_the_Ya_Ya_Sisterhood</td>
#       <td id="T_591e3_row2_col6" class="data row2 col6" ><img src=https://images.gr-assets.com/books/1408313524m/137791.jpg width=50></img></td>
#       <td id="T_591e3_row2_col7" class="data row2 col7" >divine secrets of the yaya sisterhood</td>
#       <td id="T_591e3_row2_col8" class="data row2 col8" >0.000002</td>
#       <td id="T_591e3_row2_col9" class="data row2 col9" >0.000009</td>
#     </tr>
#     <tr>
#       <th id="T_591e3_level0_row3" class="row_heading level0 row3" >1770</th>
#       <td id="T_591e3_row3_col0" class="data row3 col0" >37470</td>
#       <td id="T_591e3_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_591e3_row3_col2" class="data row3 col2" >4.000000</td>
#       <td id="T_591e3_row3_col3" class="data row3 col3" >The Other Boleyn Girl (The Plantagenet and Tudor Novels, #9)</td>
#       <td id="T_591e3_row3_col4" class="data row3 col4" >384888</td>
#       <td id="T_591e3_row3_col5" class="data row3 col5" >https://www.goodreads.com/book/show/37470.The_Other_Boleyn_Girl</td>
#       <td id="T_591e3_row3_col6" class="data row3 col6" ><img src=https://images.gr-assets.com/books/1355932638m/37470.jpg width=50></img></td>
#       <td id="T_591e3_row3_col7" class="data row3 col7" >the other boleyn girl the plantagenet and tudor novels 9</td>
#       <td id="T_591e3_row3_col8" class="data row3 col8" >0.000003</td>
#       <td id="T_591e3_row3_col9" class="data row3 col9" >0.000010</td>
#     </tr>
#     <tr>
#       <th id="T_591e3_level0_row4" class="row_heading level0 row4" >74</th>
#       <td id="T_591e3_row4_col0" class="data row4 col0" >10592</td>
#       <td id="T_591e3_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_591e3_row4_col2" class="data row4 col2" >4.000000</td>
#       <td id="T_591e3_row4_col3" class="data row4 col3" >Carrie</td>
#       <td id="T_591e3_row4_col4" class="data row4 col4" >365610</td>
#       <td id="T_591e3_row4_col5" class="data row4 col5" >https://www.goodreads.com/book/show/10592.Carrie</td>
#       <td id="T_591e3_row4_col6" class="data row4 col6" ><img src=https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png width=50></img></td>
#       <td id="T_591e3_row4_col7" class="data row4 col7" >carrie</td>
#       <td id="T_591e3_row4_col8" class="data row4 col8" >0.000003</td>
#       <td id="T_591e3_row4_col9" class="data row4 col9" >0.000011</td>
#     </tr>
#     <tr>
#       <th id="T_591e3_level0_row5" class="row_heading level0 row5" >2197</th>
#       <td id="T_591e3_row5_col0" class="data row5 col0" >5886881</td>
#       <td id="T_591e3_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_591e3_row5_col2" class="data row5 col2" >4.000000</td>
#       <td id="T_591e3_row5_col3" class="data row5 col3" >Dark Places</td>
#       <td id="T_591e3_row5_col4" class="data row5 col4" >344059</td>
#       <td id="T_591e3_row5_col5" class="data row5 col5" >https://www.goodreads.com/book/show/5886881-dark-places</td>
#       <td id="T_591e3_row5_col6" class="data row5 col6" ><img src=https://images.gr-assets.com/books/1354988288m/5886881.jpg width=50></img></td>
#       <td id="T_591e3_row5_col7" class="data row5 col7" >dark places</td>
#       <td id="T_591e3_row5_col8" class="data row5 col8" >0.000003</td>
#       <td id="T_591e3_row5_col9" class="data row5 col9" >0.000012</td>
#     </tr>
#     <tr>
#       <th id="T_591e3_level0_row6" class="row_heading level0 row6" >153</th>
#       <td id="T_591e3_row6_col0" class="data row6 col0" >11127</td>
#       <td id="T_591e3_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_591e3_row6_col2" class="data row6 col2" >5.000000</td>
#       <td id="T_591e3_row6_col3" class="data row6 col3" >The Chronicles of Narnia (Chronicles of Narnia, #1-7)</td>
#       <td id="T_591e3_row6_col4" class="data row6 col4" >382518</td>
#       <td id="T_591e3_row6_col5" class="data row6 col5" >https://www.goodreads.com/book/show/11127.The_Chronicles_of_Narnia</td>
#       <td id="T_591e3_row6_col6" class="data row6 col6" ><img src=https://images.gr-assets.com/books/1449868701m/11127.jpg width=50></img></td>
#       <td id="T_591e3_row6_col7" class="data row6 col7" >the chronicles of narnia chronicles of narnia 17</td>
#       <td id="T_591e3_row6_col8" class="data row6 col8" >0.000003</td>
#       <td id="T_591e3_row6_col9" class="data row6 col9" >0.000013</td>
#     </tr>
#     <tr>
#       <th id="T_591e3_level0_row7" class="row_heading level0 row7" >1549</th>
#       <td id="T_591e3_row7_col0" class="data row7 col0" >30118</td>
#       <td id="T_591e3_row7_col1" class="da
