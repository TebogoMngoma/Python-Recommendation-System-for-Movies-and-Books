# %% [markdown]
# # BOOK RECOMMENDATION SYSTEM
#
# ## What is a Recommendation System and Why is it important ?
#
# ![Image](books.jpg)
#
#
#
# A recommendation system is a software algorithm or system that suggests items, products, or content to users based on their preferences, behavior, or similarities to other users. These systems are designed to provide personalized and relevant recommendations, aiming to enhance user experience, engagement, and satisfaction.
#
# Recommendation systems are crucial in various domains, including e-commerce, entertainment, social media, and content streaming platforms
#
# We are going to build a Book recommendation system which can recommend us a book to read based on what are other read and also what books were rated the highest
#
# We are going to use two types of methods for our Recommendation System namely Collaborative and Content Based Filtering , on this particular we will be using Content based filtering
#
# ## Content Based Filtering
#
# This filtering method uses item features to recommend other items similar to what the user likes and also based on their previous actions or explicit feedback. If we consider the example for our book recommender system, the additional information can be the **Title**, the **Ratings**, the **Genre** e.t.c

# %%
import pandas as pd
import numpy as np
import pickle
import re
import matplotlib as plt
import json
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
import gzip
with gzip.open(r"C:\Users\PC\OneDrive\Documents\Movie Recommendation System\goodreads_books.json.gz") as f:
    line = f.readline()

# %%
data = json.loads(line)

# %%
data
# Out:
# {'isbn': '0312853122',
#  'text_reviews_count': '1',
#  'series': [],
#  'country_code': 'US',
#  'language_code': '',
#  'popular_shelves': [{'count': '3', 'name': 'to-read'},
#   {'count': '1', 'name': 'p'},
#   {'count': '1', 'name': 'collection'},
#   {'count': '1', 'name': 'w-c-fields'},
#   {'count': '1', 'name': 'biography'}],
#  'asin': '',
#  'is_ebook': 'false',
#  'average_rating': '4.00',
#  'kindle_asin': '',
#  'similar_books': [],
#  'description': '',
#  'format': 'Paperback',
#  'link': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'authors': [{'author_id': '604031', 'role': ''}],
#  'publisher': "St. Martin's Press",
#  'num_pages': '256',
#  'publication_day': '1',
#  'isbn13': '9780312853129',
#  'publication_month': '9',
#  'edition_information': '',
#  'publication_year': '1984',
#  'url': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'image_url': 'https://images.gr-assets.com/books/1310220028m/5333265.jpg',
#  'book_id': '5333265',
#  'ratings_count': '3',
#  'work_id': '5400751',
#  'title': 'W.C. Fields: A Life on Film',
#  'title_without_series': 'W.C. Fields: A Life on Film'}

# %%
def parse_fields(line):
    data = json.loads(line)
    return {
        "book_id" : data["book_id"],
        "title" : data["title_without_series"],
        "ratings" : data["ratings_count"],
        "url" : data["url"],
        "cover_image" : data["image_url"]
        }

# %%
book_titles = []
with gzip.open(r"C:\Users\PC\OneDrive\Documents\Movie Recommendation System\goodreads_books.json.gz" ,"r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        fields = parse_fields(line)
        try :
            ratings = int(fields["ratings"])
        except ValueError:
            continue
        if ratings > 15:
            book_titles.append(fields)

# %% [markdown]
# Convert gzip file and preprocess to Pandas DataFrame

# %%
titles = pd.DataFrame.from_dict(book_titles)

# %% [markdown]
# Data Cleaning

# %%
# Turn ratings column dtype to numeric 
titles["ratings"] = pd.to_numeric(titles['ratings'])

# %%
# Clean Title column
titles["title_clean"] = titles["title"].replace(r"[^\w\s]", '', regex=True)

# %%
# lower characters 
titles["title_clean"] = titles["title_clean"].str.lower()

# %%
#remove spaces in a row with single space
titles["title_clean"] = titles["title_clean"].str.replace("\s+"," ",regex=True)

# %%
#remove any columns with no title 
titles = titles[titles["title_clean"].str.len()>0]

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/7327624-th...
# 1        https://www.goodreads.com/book/show/6066819-be...
# 2        https://www.goodreads.com/book/show/287141.The...
# 3        https://www.goodreads.com/book/show/6066812-al...
# 4        https://www.goodreads.com/book/show/287149.The...
# ...                                                    ...
# 1308952  https://www.goodreads.com/book/show/17805813-o...
# 1308953  https://www.goodreads.com/book/show/331839.Jac...
# 1308954  https://www.goodreads.com/book/show/2685097-th...
# 1308955  https://www.goodreads.com/book/show/2342551.Th...
# 1308956  https://www.goodreads.com/book/show/22017381-1...
#
#                                                cover_image  \
# 0        https://images.gr-assets.com/books/1304100136m...
# 1        https://s.gr-assets.com/assets/nophoto/book/11...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://images.gr-assets.com/books/1316637798m...
# 4        https://images.gr-assets.com/books/1328768789m...
# ...                                                    ...
# 1308952  https://images.gr-assets.com/books/1379766592m...
# 1308953  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308954  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308955  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308956  https://images.gr-assets.com/books/1398621236m...
#
#                                               title_clean
# 0          the unschooled wizard sun wolf and starhawk 12
# 1                                    best friends forever
# 2                           the aeneid for boys and girls
# 3        alls fairy in love and war avalon web of magic 8
# 4                                     the devils notebook
# ...                                                   ...
# 1308952                          ondine ondine quartet 05
# 1308953     jacqueline kennedy onassis friend of the arts
# 1308954                   the spaniards blackmailed bride
# 1308955           the childrens classic poetry collection
# 1308956               101 nights volume one 101 nights 13
#
# [1308951 rows x 6 columns]

# %%
titles.to_json("book_titles.json")

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/7327624-th...
# 1        https://www.goodreads.com/book/show/6066819-be...
# 2        https://www.goodreads.com/book/show/287141.The...
# 3        https://www.goodreads.com/book/show/6066812-al...
# 4        https://www.goodreads.com/book/show/287149.The...
# ...                                                    ...
# 1308952  https://www.goodreads.com/book/show/17805813-o...
# 1308953  https://www.goodreads.com/book/show/331839.Jac...
# 1308954  https://www.goodreads.com/book/show/2685097-th...
# 1308955  https://www.goodreads.com/book/show/2342551.Th...
# 1308956  https://www.goodreads.com/book/show/22017381-1...
#
#                                                cover_image  \
# 0        https://images.gr-assets.com/books/1304100136m...
# 1        https://s.gr-assets.com/assets/nophoto/book/11...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://images.gr-assets.com/books/1316637798m...
# 4        https://images.gr-assets.com/books/1328768789m...
# ...                                                    ...
# 1308952  https://images.gr-assets.com/books/1379766592m...
# 1308953  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308954  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308955  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308956  https://images.gr-assets.com/books/1398621236m...
#
#                                               title_clean
# 0          the unschooled wizard sun wolf and starhawk 12
# 1                                    best friends forever
# 2                           the aeneid for boys and girls
# 3        alls fairy in love and war avalon web of magic 8
# 4                                     the devils notebook
# ...                                                   ...
# 1308952                          ondine ondine quartet 05
# 1308953     jacqueline kennedy onassis friend of the arts
# 1308954                   the spaniards blackmailed bride
# 1308955           the childrens classic poetry collection
# 1308956               101 nights volume one 101 nights 13
#
# [1308951 rows x 6 columns]

# %% [markdown]
# Creating Search Engine

# %%
vectorizer = TfidfVectorizer()

# %%
tfidf = vectorizer.fit_transform(titles["title_clean"])

# %%
def show_book_image(val):
    return '<img src="{}" width = 100></img'.format(val)

# %%
def search(query,vectorizer):
    processed = re.sub(r"[^\w\s]", '',query.lower())
    query_vect = vectorizer.transform([processed])
    similarity = cosine_similarity(query_vect,tfidf).flatten()
    indices = np.argpartition(similarity,-10)[-10:]
    results = titles.iloc[indices]
    results = results.sort_values("ratings",ascending=False)
    return results.head(5).style.format({'cover_image': show_book_image})

# %%
search("The Devils Notebook" ,vectorizer)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0e415">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e415_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_0e415_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_0e415_level0_col2" class="col_heading level0 col2" >ratings</th>
#       <th id="T_0e415_level0_col3" class="col_heading level0 col3" >url</th>
#       <th id="T_0e415_level0_col4" class="col_heading level0 col4" >cover_image</th>
#       <th id="T_0e415_level0_col5" class="col_heading level0 col5" >title_clean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e415_level0_row0" class="row_heading level0 row0" >374879</th>
#       <td id="T_0e415_row0_col0" class="data row0 col0" >15931</td>
#       <td id="T_0e415_row0_col1" class="data row0 col1" >The Notebook (The Notebook, #1)</td>
#       <td id="T_0e415_row0_col2" class="data row0 col2" >1064723</td>
#       <td id="T_0e415_row0_col3" class="data row0 col3" >https://www.goodreads.com/book/show/15931.The_Notebook</td>
#       <td id="T_0e415_row0_col4" class="data row0 col4" ><img src="https://images.gr-assets.com/books/1385738917m/15931.jpg" width = 100></img</td>
#       <td id="T_0e415_row0_col5" class="data row0 col5" >the notebook the notebook 1</td>
#     </tr>
#     <tr>
#       <th id="T_0e415_level0_row1" class="row_heading level0 row1" >544207</th>
#       <td id="T_0e415_row1_col0" class="data row1 col0" >336903</td>
#       <td id="T_0e415_row1_col1" class="data row1 col1" >The Notebook</td>
#       <td id="T_0e415_row1_col2" class="data row1 col2" >2243</td>
#       <td id="T_0e415_row1_col3" class="data row1 col3" >https://www.goodreads.com/book/show/336903.The_Notebook</td>
#       <td id="T_0e415_row1_col4" class="data row1 col4" ><img src="https://images.gr-assets.com/books/1307040326m/336903.jpg" width = 100></img</td>
#       <td id="T_0e415_row1_col5" class="data row1 col5" >the notebook</td>
#     </tr>
#     <tr>
#       <th id="T_0e415_level0_row2" class="row_heading level0 row2" >749489</th>
#       <td id="T_0e415_row2_col0" class="data row2 col0" >1250158</td>
#       <td id="T_0e415_row2_col1" class="data row2 col1" >The Notebook</td>
#       <td id="T_0e415_row2_col2" class="data row2 col2" >1273</td>
#       <td id="T_0e415_row2_col3" class="data row2 col3" >https://www.goodreads.com/book/show/1250158.The_Notebook</td>
#       <td id="T_0e415_row2_col4" class="data row2 col4" ><img src="https://images.gr-assets.com/books/1317877007m/1250158.jpg" width = 100></img</td>
#       <td id="T_0e415_row2_col5" class="data row2 col5" >the notebook</td>
#     </tr>
#     <tr>
#       <th id="T_0e415_level0_row3" class="row_heading level0 row3" >1258536</th>
#       <td id="T_0e415_row3_col0" class="data row3 col0" >3472</td>
#       <td id="T_0e415_row3_col1" class="data row3 col1" >The Notebook</td>
#       <td id="T_0e415_row3_col2" class="data row3 col2" >1270</td>
#       <td id="T_0e415_row3_col3" class="data row3 col3" >https://www.goodreads.com/book/show/3472.The_Notebook</td>
#       <td id="T_0e415_row3_col4" class="data row3 col4" ><img src="https://images.gr-assets.com/books/1434857904m/3472.jpg" width = 100></img</td>
#       <td id="T_0e415_row3_col5" class="data row3 col5" >the notebook</td>
#     </tr>
#     <tr>
#       <th id="T_0e415_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0e415_row4_col0" class="data row4 col0" >287149</td>
#       <td id="T_0e415_row4_col1" class="data row4 col1" >The Devil's Notebook</td>
#       <td id="T_0e415_row4_col2" class="data row4 col2" >986</td>
#       <td id="T_0e415_row4_col3" class="data row4 col3" >https://www.goodreads.com/book/show/287149.The_Devil_s_Notebook</td>
#       <td id="T_0e415_row4_col4" class="data row4 col4" ><img src="https://images.gr-assets.com/books/1328768789m/287149.jpg" width = 100></img</td>
#       <td id="T_0e415_row4_col5" class="data row4 col5" >the devils notebook</td>
#     </tr>
#   </tbody>
# </table>
